# %%
import pandas as pd

# %% [markdown]
# Learned from: Corey Schafer
# https://www.youtube.com/playlist?list=PL-osiE80TeTsWmV9i9c58mdDCSskIFdDS

# %%
df = pd.read_csv('data_files/survey_results_public.csv')
#df
schema_df = pd.read_csv('data_files/survey_results_schema.csv')
pd.set_option('display.max_columns',79)
pd.set_option('display.max_rows',79)

# %%
df.head()
# Out:
#    ResponseId                                         MainBranch  \
# 0           1                                      None of these
# 1           2                     I am a developer by profession
# 2           3  I am not primarily a developer, but I write co...
# 3           4                     I am a developer by profession
# 4           5                     I am a developer by profession
#
#             Employment                            RemoteWork  \
# 0                  NaN                                   NaN
# 1  Employed, full-time                          Fully remote
# 2  Employed, full-time  Hybrid (some remote, some in-person)
# 3  Employed, full-time                          Fully remote
# 4  Employed, full-time  Hybrid (some remote, some in-person)
#
#                            CodingActivities  \
# 0                                       NaN
# 1  Hobby;Contribute to open-source projects
# 2                                     Hobby
# ...

# %%
felt = df['Country'] == 'India'
felt
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 73263    False
# 73264    False
# 73265    False
# 73266    False
# 73267    False
# Name: Country, Length: 73268, dtype: bool

# %%
india_df = df.loc[felt]
india_df.head()
# Out:
#      ResponseId                      MainBranch  \
# 6             7     I code primarily as a hobby
# 7             8  I am a developer by profession
# 65           66  I am a developer by profession
# 140         141  I am a developer by profession
# 151         152  I am a developer by profession
#
#                              Employment                            RemoteWork  \
# 6                    Student, part-time                                   NaN
# 7    Not employed, but looking for work                                   NaN
# 65                  Employed, full-time  Hybrid (some remote, some in-person)
# 140                 Employed, full-time  Hybrid (some remote, some in-person)
# 151                 Employed, full-time                        Full in-person
#
#                   CodingActivities  \
# 6                              NaN
# 7                              NaN
# 65   Hobby;Other (please specify):
# 140   I don’t code outside of work
# ...

# %%
india_df.to_csv('data_files/modified.csv') #creating new csv file

# %%
india_df.to_csv('data_files/modified.csv', sep='\t') #creating new csv file with tab space value

# %%
india_df.to_excel('data_files/modified.xlsx')  #creating new excel file

# %%
test = pd.read_excel('data_files/modified.xlsx')
test.head()
# Out:
#    Unnamed: 0  ResponseId                      MainBranch  \
# 0           6           7     I code primarily as a hobby
# 1           7           8  I am a developer by profession
# 2          65          66  I am a developer by profession
# 3         140         141  I am a developer by profession
# 4         151         152  I am a developer by profession
#
#                            Employment                            RemoteWork  \
# 0                  Student, part-time                                   NaN
# 1  Not employed, but looking for work                                   NaN
# 2                 Employed, full-time  Hybrid (some remote, some in-person)
# 3                 Employed, full-time  Hybrid (some remote, some in-person)
# 4                 Employed, full-time                        Full in-person
#
#                 CodingActivities  \
# 0                            NaN
# 1                            NaN
# 2  Hobby;Other (please specify):
# ...

# %%
# india_df.to_json('data_files/modified.json') # creating json file
india_df.to_json('data_files/modified.json', orient='records', lines=True) # creating in list format default dictionary format

# %%
test = pd.read_json('data_files/modified.json', orient='records', lines=True)
test.head()
# Out:
#    ResponseId                      MainBranch  \
# 0           7     I code primarily as a hobby
# 1           8  I am a developer by profession
# 2          66  I am a developer by profession
# 3         141  I am a developer by profession
# 4         152  I am a developer by profession
#
#                            Employment                            RemoteWork  \
# 0                  Student, part-time                                  None
# 1  Not employed, but looking for work                                  None
# 2                 Employed, full-time  Hybrid (some remote, some in-person)
# 3                 Employed, full-time  Hybrid (some remote, some in-person)
# 4                 Employed, full-time                        Full in-person
#
#                 CodingActivities  \
# 0                           None
# 1                           None
# 2  Hobby;Other (please specify):
# 3   I don’t code outside of work
# 4                          Hobby
#
# ...

# %% [markdown]
# # Reading data form mysql database

# %%
from pymysql import connect

# %%
#connect to database
data_base = connect(host= 'localhost', user='root', passwd='mysqlroot12') 
cur = data_base.cursor()
# query
query = 'show databases'
cur.execute(query)
#fetch all data bases
databases = cur.fetchall()
for database in databases:
    print(database)
# Out:
# ('classicmodels',)
# ('codanicsdb',)
# ('information_schema',)
# ('institute_management',)
# ('mysql',)
# ('performance_schema',)
# ('sys',)

# %%
#connect to database
data_base = connect(host= 'localhost', user='root', passwd='mysqlroot12', database='classicmodels')
cur = data_base.cursor()
# query
query = 'show tables'
cur.execute(query)
#fetch all data bases
data_bases = cur.fetchall()
data_bases
# for data in data_bases:
#     print(data)
# Out:
# (('customers',),
#  ('employees',),
#  ('offices',),
#  ('orderdetails',),
#  ('orders',),
#  ('payments',),
#  ('productlines',),
#  ('products',))

# %%
panda_dataframe = pd.read_sql(query, data_base)
display(panda_dataframe)
# Out:
# C:\Users\asgha\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\io\sql.py:761: UserWarning: pandas only support SQLAlchemy connectable(engine/connection) ordatabase string URI or sqlite3 DBAPI2 connectionother DBAPI2 objects are not tested, please consider using SQLAlchemy
#   warnings.warn(
#   Tables_in_classicmodels
# 0               customers
# 1               employees
# 2                 offices
# 3            orderdetails
# 4                  orders
# 5                payments
# 6            productlines
# 7                products

# %%
query = "select * from customers"
panda_dataframe = pd.read_sql(query, data_base)
display(panda_dataframe)
# Out:
# C:\Users\asgha\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\io\sql.py:761: UserWarning: pandas only support SQLAlchemy connectable(engine/connection) ordatabase string URI or sqlite3 DBAPI2 connectionother DBAPI2 objects are not tested, please consider using SQLAlchemy
#   warnings.warn(
#      customerNumber                    customerName contactLastName  \
# 0               103               Atelier graphique         Schmitt
# 1               112              Signal Gift Stores            King
# 2               114      Australian Collectors, Co.        Ferguson
# 3               119               La Rochelle Gifts         Labrune
# 4               121              Baane Mini Imports      Bergulfsen
# ..              ...                             ...             ...
# 117             486    Motor Mint Distributors Inc.         Salazar
# 118             487        Signal Collectibles Ltd.          Taylor
# ...

# %%
# readin data from json file link 
read_url =pd.read_json('https://jsonplaceholder.typicode.com/posts')
read_url.head()
# Out:
#    userId  id                                              title  \
# 0       1   1  sunt aut facere repellat provident occaecati e...
# 1       1   2                                       qui est esse
# 2       1   3  ea molestias quasi exercitationem repellat qui...
# 3       1   4                               eum et est occaecati
# 4       1   5                                 nesciunt quas odio
#
#                                                 body
# 0  quia et suscipit\nsuscipit recusandae consequu...
# 1  est rerum tempore vitae\nsequi sint nihil repr...
# 2  et iusto sed quo iure\nvoluptatem occaecati om...
# 3  ullam et saepe reiciendis voluptatem adipisci\...
# 4  repudiandae veniam quaerat sunt sed\nalias aut...
